# %% [markdown]
# ###  Imports, Configurations

# %%
# %%capture
# %load_ext rpy2.ipython

# %%
# %%capture
# %reload_ext rpy2.ipython

# %%
import ecf
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix

# %%
# %%capture
# %%R
install.packages("dplyr")

# %%
# %%capture
# %%R
library('dplyr')

# %% [markdown]
# ### Preprocessing

# %%
# %%R
# # Data processing in line with the original ProPublica analysis.
# # Same code piece as in the original.
# raw_data <- read.csv("./scores-two-years-violent.csv")
# df <- dplyr::select(raw_data, age, c_charge_degree, race, age_cat, v_score_text, sex, priors_count,
#                     days_b_screening_arrest, v_decile_score, is_recid, two_year_recid) %>%
#         filter(days_b_screening_arrest <= 30) %>%
#         filter(days_b_screening_arrest >= -30) %>%
#         filter(is_recid != -1) %>%
#         filter(c_charge_degree != "O") %>%
#         filter(v_score_text != 'N/A')
#
#
# # Write preprocessed data
# write.csv(df, 'violent.csv')

# %% [markdown]
# ### Descriptive Statistics

# %%
compasdata = pd.read_csv('violent.csv').loc[:, ['race', 'sex', 'v_score_text', 'two_year_recid']]
compasdata['v_score_text'] = np.where(compasdata['v_score_text'] == 'Low', 0, 1)
compasdata.columns = ['race', 'sex', 'recid_pred', 'recid_gt']
compasdata['intersection'] = compasdata["sex"] + ' - ' + compasdata["race"]
compasdata = compasdata.astype('string')

# %%
compasdata.head()
# Out:
#                race     sex recid_pred recid_gt             intersection
# 0             Other    Male          0        0             Male - Other
# 1  African-American    Male          0        1  Male - African-American
# 2             Other    Male          0        0             Male - Other
# 3             Other    Male          0        0             Male - Other
# 4         Caucasian  Female          0        0       Female - Caucasian

# %%
print('Table III')

table_3 = pd.DataFrame(compasdata.groupby(['race', 'sex']).size()).reset_index().pivot(index='race', columns='sex', values=0).fillna(0)

grand_total = table_3.sum().sum()

table_3['Total'] = table_3.sum(axis=1)
table_3.loc['Total'] = table_3.sum(axis=0)

table_3['%'] = table_3['Total'] / grand_total * 100
table_3.loc['%'] = table_3.sum(axis=0) / 2 / grand_total * 100
table_3.loc['%', '%'] = 0
table_3.round().astype(int)
# Out:
# Table III
# sex               Female  Male    Total   %
# race
# African-American     393    1525    1918      48
# Asian                  1      25      26       1
# Caucasian            336    1123    1459      36
# Hispanic              61     294     355       9
# Native American        0       7       7       0
# Other                 50     205     255       6
# Total                841    3179    4020     100
# %                     21      79     100       0

# %%
print('Table IV')

table_4 = pd.DataFrame(confusion_matrix(compasdata['recid_gt'], compasdata['recid_pred']), index = ['-', '+'], columns = ['-', '+'])
table_4.columns.name, table_4.index.name = 'Predicted', 'Actual'
table_4 = table_4.loc[['+', '-'], ['+', '-']].transpose()


grand_total = table_4.sum().sum()

table_4['Total'] = table_4.sum(axis=1)
table_4.loc['Total'] = table_4.sum(axis=0)

table_4['%'] = table_4['Total'] / grand_total * 100
table_4.loc['%'] = table_4.sum(axis=0) / 2 / grand_total * 100
table_4.loc['%', '%'] = 0
table_4.round().astype(int)
# Out:
# Table IV
# Actual       +     -  Total    %
# Predicted
# +          346   761   1107   28
# -          306  2607   2913   72
# Total      652  3368   4020  100
# %           16    84    100    0

# %% [markdown]
# ## Fairness Analysis

# %% [markdown]
# ### 1) Sex

# %%
result = ecf.ecf(sampledata=compasdata, s = 'sex', pred = 'recid_pred', gt = 'recid_gt')

# %%
print('TABLE V')
print('\n************\n')

print('Table V - Observed (Columns O)')
display(result['contingency'].sort_index().reindex(sorted(result['contingency'].columns, reverse=True), axis=1))

print('\n************\n')

print('Table V - Expected (Columns E)')
display(np.round(result['equal_confusion_test']['expected']).sort_index().reindex(sorted(result['equal_confusion_test']['expected'].columns, reverse=True), axis=1).style.format('{0:,.0f}'))

print('\n************\n')

print("Table V - Residuals (Columns R)")
display(result['posthoc_analysis'].sort_index().reindex(sorted(result['posthoc_analysis'].columns, reverse=True), axis=1).round(1))
# Out:
# TABLE V
#
# ************
#
# Table V - Observed (Columns O)
# Actual       1         0
# Predicted    1    0    1     0
# Female      27   50  137   627
# Male       319  256  624  1980
# ************
#
# Table V - Expected (Columns E)
# <style type="text/css">
# </style>
# <table id="T_530cd">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Actual</th>
#       <th id="T_530cd_level0_col0" class="col_heading level0 col0" colspan="2">1</th>
#       <th id="T_530cd_level0_col2" class="col_heading level0 col2" colspan="2">0</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted</th>
#       <th id="T_530cd_level1_col0" class="col_heading level1 col0" >1</th>
#       <th id="T_530cd_level1_col1" class="col_heading level1 col1" >0</th>
#       <th id="T_530cd_level1_col2" class="col_heading level1 col2" >1</th>
#       <th id="T_530cd_level1_col3" class="col_heading level1 col3" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_530cd_level0_row0" class="row_heading level0 row0" >Female</th>
#       <td id="T_530cd_row0_col0" class="data row0 col0" >72</td>
#       <td id="T_530cd_row0_col1" class="data row0 col1" >64</td>
#       <td id="T_530cd_row0_col2" class="data row0 col2" >159</td>
#       <td id="T_530cd_row0_col3" class="data row0 col3" >545</td>
#     </tr>
#     <tr>
#       <th id="T_530cd_level0_row1" class="row_heading level0 row1" >Male</th>
#       <td id="T_530cd_row1_col0" class="data row1 col0" >274</td>
#       <td id="T_530cd_row1_col1" class="data row1 col1" >242</td>
#       <td id="T_530cd_row1_col2" class="data row1 col2" >602</td>
#       <td id="T_530cd_row1_col3" class="data row1 col3" >2,062</td>
#     </tr>
#   </tbody>
# </table>
# ************
#
# Table V - Residuals (Columns R)
# Actual       1         0
# Predicted    1    0    1    0
# Female    -6.3 -2.0 -2.2  6.6
# Male       6.3  2.0  2.2 -6.6

# %%
print('Sex: Equal confusion test p-value is', round(result['equal_confusion_test']['p'], 5))

print('\n************\n')

print('Sex: Confusion parity error is', round(result['confusion_parity_error'], 3))
# Out:
# Sex: Equal confusion test p-value is 0.0
#
# ************
#
# Sex: Confusion parity error is 0.121

# %%
print('TABLE VII')
print('\n************\n')


print("Table VII - Top Panel - Proportion of Row Totals")
display((result['ratio_all'][1]*100).sort_index().sort_index(axis=1, ascending=False).style.format('{0:,.0f}%'))

print('\n************\n')

print("Table VII - Top Panel - Proportion of Subtotals")
display((result['ratio_pred']*100).sort_index().sort_index(axis=1, ascending=False).style.format('({0:,.0f}%)'))

print('\n************\n')

print("Table VII - Bottom Panel - Proportion of Row Totals")
display((result['ratio_all'][0]*100).sort_index().sort_index(axis=1, ascending=False).style.format('{0:,.0f}%'))

print('\n************\n')

print("Table VII - Bottom Panel - Proportion of Subtotals")
display((result['ratio_gt']*100).sort_index().sort_index(axis=1, ascending=False).style.format('({0:,.0f}%)'))
# Out:
# TABLE VII
#
# ************
#
# Table VII - Top Panel - Proportion of Row Totals
# <style type="text/css">
# </style>
# <table id="T_14f7a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Predicted</th>
#       <th id="T_14f7a_level0_col0" class="col_heading level0 col0" colspan="2">1</th>
#       <th id="T_14f7a_level0_col2" class="col_heading level0 col2" colspan="2">0</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Actual</th>
#       <th id="T_14f7a_level1_col0" class="col_heading level1 col0" >1</th>
#       <th id="T_14f7a_level1_col1" class="col_heading level1 col1" >0</th>
#       <th id="T_14f7a_level1_col2" class="col_heading level1 col2" >1</th>
#       <th id="T_14f7a_level1_col3" class="col_heading level1 col3" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14f7a_level0_row0" class="row_heading level0 row0" >Female</th>
#       <td id="T_14f7a_row0_col0" class="data row0 col0" >3%</td>
#       <td id="T_14f7a_row0_col1" class="data row0 col1" >16%</td>
#       <td id="T_14f7a_row0_col2" class="data row0 col2" >6%</td>
#       <td id="T_14f7a_row0_col3" class="data row0 col3" >75%</td>
#     </tr>
#     <tr>
#       <th id="T_14f7a_level0_row1" class="row_heading level0 row1" >Male</th>
#       <td id="T_14f7a_row1_col0" class="data row1 col0" >10%</td>
#       <td id="T_14f7a_row1_col1" class="data row1 col1" >20%</td>
#       <td id="T_14f7a_row1_col2" class="data row1 col2" >8%</td>
#       <td id="T_14f7a_row1_col3" class="data row1 col3" >62%</td>
#     </tr>
#   </tbody>
# </table>
# ************
#
# Table VII - Top Panel - Proportion of Subtotals
# <style type="text/css">
# </style>
# <table id="T_90612">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Predicted</th>
#       <th id="T_90612_level0_col0" class="col_heading level0 col0" colspan="2">1</th>
#       <th id="T_90612_level0_col2" class="col_heading level0 col2" colspan="2">0</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Actual</th>
#       <th id="T_90612_level1_col0" class="col_heading level1 col0" >1</th>
#       <th id="T_90612_level1_col1" class="col_heading level1 col1" >0</th>
#       <th id="T_90612_level1_col2" class="col_heading level1 col2" >1</th>
#       <th id="T_90612_level1_col3" class="col_heading level1 col3" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90612_level0_row0" class="row_heading level0 row0" >Female</th>
#       <td id="T_90612_row0_col0" class="data row0 col0" >(16%)</td>
#       <td id="T_90612_row0_col1" class="data row0 col1" >(84%)</td>
#       <td id="T_90612_row0_col2" class="data row0 col2" >(7%)</td>
#       <td id="T_90612_row0_col3" class="data row0 col3" >(93%)</td>
#     </tr>
#     <tr>
#       <th id="T_90612_level0_row1" class="row_heading level0 row1" >Male</th>
#       <td id="T_90612_row1_col0" class="data row1 col0" >(34%)</td>
#       <td id="T_90612_row1_col1" class="data row1 col1" >(66%)</td>
#       <td id="T_90612_row1_col2" class="data row1 col2" >(11%)</td>
#       <td id="T_90612_row1_col3" class="data row1 col3" >(89%)</td>
#     </tr>
#   </tbody>
# </table>
# ************
#
# Table VII - Bottom Panel - Proportion of Row Totals
# <style type="text/css">
# </style>
# <table id="T_cfd6a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Actual</th>
#       <th id="T_cfd6a_level0_col0" class="col_heading level0 col0" colspan="2">1</th>
#       <th id="T_cfd6a_level0_col2" class="col_heading level0 col2" colspan="2">0</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted</th>
#       <th id="T_cfd6a_level1_col0" class="col_heading level1 col0" >1</th>
#       <th id="T_cfd6a_level1_col1" class="col_heading level1 col1" >0</th>
#       <th id="T_cfd6a_level1_col2" class="col_heading level1 col2" >1</th>
#       <th id="T_cfd6a_level1_col3" class="col_heading level1 col3" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cfd6a_level0_row0" class="row_heading level0 row0" >Female</th>
#       <td id="T_cfd6a_row0_col0" class="data row0 col0" >3%</td>
#       <td id="T_cfd6a_row0_col1" class="data row0 col1" >6%</td>
#       <td id="T_cfd6a_row0_col2" class="data row0 col2" >16%</td>
#       <td id="T_cfd6a_row0_col3" class="data row0 col3" >75%</td>
#     </tr>
#     <tr>
#       <th id="T_cfd6a_level0_row1" class="row_heading level0 row1" >Male</th>
#       <td id="T_cfd6a_row1_col0" class="data row1 col0" >10%</td>
#       <td id="T_cfd6a_row1_col1" class="data row1 col1" >8%</td>
#       <td id="T_cfd6a_row1_col2" class="data row1 col2" >20%</td>
#       <td id="T_cfd6a_row1_col3" class="data row1 col3" >62%</td>
#     </tr>
#   </tbody>
# </table>
# ************
#
# Table VII - Bottom Panel - Proportion of Subtotals
# <style type="text/css">
# </style>
# <table id="T_47344">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Actual</th>
#       <th id="T_47344_level0_col0" class="col_heading level0 col0" colspan="2">1</th>
#       <th id="T_47344_level0_col2" class="col_heading level0 col2" colspan="2">0</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted</th>
#       <th id="T_47344_level1_col0" class="col_heading level1 col0" >1</th>
#       <th id="T_47344_level1_col1" class="col_heading level1 col1" >0</th>
#       <th id="T_47344_level1_col2" class="col_heading level1 col2" >1</th>
#       <th id="T_47344_level1_col3" class="col_heading level1 col3" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47344_level0_row0" class="row_heading level0 row0" >Female</th>
#       <td id="T_47344_row0_col0" class="data row0 col0" >(35%)</td>
#       <td id="T_47344_row0_col1" class="data row0 col1" >(65%)</td>
#       <td id="T_47344_row0_col2" class="data row0 col2" >(18%)</td>
#       <td id="T_47344_row0_col3" class="data row0 col3" >(82%)</td>
#     </tr>
#     <tr>
#       <th id="T_47344_level0_row1" class="row_heading level0 row1" >Male</th>
#       <td id="T_47344_row1_col0" class="data row1 col0" >(55%)</td>
#       <td id="T_47344_row1_col1" class="data row1 col1" >(45%)</td>
#       <td id="T_47344_row1_col2" class="data row1 col2" >(24%)</td>
#       <td id="T_47344_row1_col3" class="data row1 col3" >(76%)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 2) Race

# %%
result = ecf.ecf(sampledata=compasdata, s = 'race', pred = 'recid_pred', gt = 'recid_gt')

# %%
print('TABLE VI')
print('\n************\n')

print('Table VI - Observed (Columns O)')
display(result['contingency'].sort_index().reindex(sorted(result['contingency'].columns, reverse=True), axis=1))

print('\n************\n')

print('Table VI - Expected (Columns E)')
display(np.round(result['equal_confusion_test']['expected']).sort_index().reindex(sorted(result['equal_confusion_test']['expected'].columns, reverse=True), axis=1).style.format('{0:,.0f}'))

print('\n************\n')

print("Table VI - Residuals (Columns R)")
display(result['posthoc_analysis'].sort_index().reindex(sorted(result['posthoc_analysis'].columns, reverse=True), axis=1).round(1))
# Out:
# TABLE VI
#
# ************
#
# Table VI - Observed (Columns O)
# Actual              1         0
# Predicted           1    0    1     0
# African-American  250  154  468  1046
# Asian               3    0    1    22
# Caucasian          64  110  198  1087
# Hispanic           10   25   61   259
# Native American     1    0    1     5
# Other              18   17   32   188
# ************
#
# Table VI - Expected (Columns E)
# <style type="text/css">
# </style>
# <table id="T_5b24c">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Actual</th>
#       <th id="T_5b24c_level0_col0" class="col_heading level0 col0" colspan="2">1</th>
#       <th id="T_5b24c_level0_col2" class="col_heading level0 col2" colspan="2">0</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted</th>
#       <th id="T_5b24c_level1_col0" class="col_heading level1 col0" >1</th>
#       <th id="T_5b24c_level1_col1" class="col_heading level1 col1" >0</th>
#       <th id="T_5b24c_level1_col2" class="col_heading level1 col2" >1</th>
#       <th id="T_5b24c_level1_col3" class="col_heading level1 col3" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b24c_level0_row0" class="row_heading level0 row0" >African-American</th>
#       <td id="T_5b24c_row0_col0" class="data row0 col0" >165</td>
#       <td id="T_5b24c_row0_col1" class="data row0 col1" >146</td>
#       <td id="T_5b24c_row0_col2" class="data row0 col2" >363</td>
#       <td id="T_5b24c_row0_col3" class="data row0 col3" >1,244</td>
#     </tr>
#     <tr>
#       <th id="T_5b24c_level0_row1" class="row_heading level0 row1" >Asian</th>
#       <td id="T_5b24c_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_5b24c_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_5b24c_row1_col2" class="data row1 col2" >5</td>
#       <td id="T_5b24c_row1_col3" class="data row1 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_5b24c_level0_row2" class="row_heading level0 row2" >Caucasian</th>
#       <td id="T_5b24c_row2_col0" class="data row2 col0" >126</td>
#       <td id="T_5b24c_row2_col1" class="data row2 col1" >111</td>
#       <td id="T_5b24c_row2_col2" class="data row2 col2" >276</td>
#       <td id="T_5b24c_row2_col3" class="data row2 col3" >946</td>
#     </tr>
#     <tr>
#       <th id="T_5b24c_level0_row3" class="row_heading level0 row3" >Hispanic</th>
#       <td id="T_5b24c_row3_col0" class="data row3 col0" >31</td>
#       <td id="T_5b24c_row3_col1" class="data row3 col1" >27</td>
#       <td id="T_5b24c_row3_col2" class="data row3 col2" >67</td>
#       <td id="T_5b24c_row3_col3" class="data row3 col3" >230</td>
#     </tr>
#     <tr>
#       <th id="T_5b24c_level0_row4" class="row_heading level0 row4" >Native American</th>
#       <td id="T_5b24c_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_5b24c_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_5b24c_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_5b24c_row4_col3" class="data row4 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_5b24c_level0_row5" class="row_heading level0 row5" >Other</th>
#       <td id="T_5b24c_row5_col0" class="data row5 col0" >22</td>
#       <td id="T_5b24c_row5_col1" class="data row5 col1" >19</td>
#       <td id="T_5b24c_row5_col2" class="data row5 col2" >48</td>
#       <td id="T_5b24c_row5_col3" class="data row5 col3" >165</td>
#     </tr>
#   </tbody>
# </table>
# ************
#
# Table VI - Residuals (Columns R)
# Actual              1         0
# Predicted           1    0    1     0
# African-American  9.6  1.0  8.5 -13.1
# Asian             0.5 -1.5 -2.0   2.1
# Caucasian        -7.2 -0.1 -6.5   9.7
# Hispanic         -4.1 -0.4 -0.9   3.4
# Native American   0.5 -0.8 -0.3   0.4
# Other            -0.9 -0.6 -2.7   3.1

# %%
print('Race: Equal confusion test p-value is', round(result['equal_confusion_test']['p'], 5))

print('\n************\n')

print('Race: Confusion parity error is', round(result['confusion_parity_error'], 3))
# Out:
# Race: Equal confusion test p-value is 0.0
#
# ************
#
# Race: Confusion parity error is 0.133

# %%
print('TABLE VIII')
print('\n************\n')


print("Table VIII - Top Panel - Proportion of Row Totals")
display((result['ratio_all'][1]*100).sort_index().sort_index(axis=1, ascending=False).style.format('{0:,.0f}%'))

print('\n************\n')

print("Table VIII - Top Panel - Proportion of Subtotals")
display((result['ratio_pred']*100).sort_index().sort_index(axis=1, ascending=False).style.format('({0:,.0f}%)'))

print('\n************\n')

print("Table VIII - Bottom Panel - Proportion of Row Totals")
display((result['ratio_all'][0]*100).sort_index().sort_index(axis=1, ascending=False).style.format('{0:,.0f}%'))

print('\n************\n')

print("Table VIII - Bottom Panel - Proportion of Subtotals")
display((result['ratio_gt']*100).sort_index().sort_index(axis=1, ascending=False).style.format('({0:,.0f}%)'))
# Out:
# TABLE VIII
#
# ************
#
# Table VIII - Top Panel - Proportion of Row Totals
# <style type="text/css">
# </style>
# <table id="T_83f72">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Predicted</th>
#       <th id="T_83f72_level0_col0" class="col_heading level0 col0" colspan="2">1</th>
#       <th id="T_83f72_level0_col2" class="col_heading level0 col2" colspan="2">0</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Actual</th>
#       <th id="T_83f72_level1_col0" class="col_heading level1 col0" >1</th>
#       <th id="T_83f72_level1_col1" class="col_heading level1 col1" >0</th>
#       <th id="T_83f72_level1_col2" class="col_heading level1 col2" >1</th>
#       <th id="T_83f72_level1_col3" class="col_heading level1 col3" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83f72_level0_row0" class="row_heading level0 row0" >African-American</th>
#       <td id="T_83f72_row0_col0" class="data row0 col0" >13%</td>
#       <td id="T_83f72_row0_col1" class="data row0 col1" >24%</td>
#       <td id="T_83f72_row0_col2" class="data row0 col2" >8%</td>
#       <td id="T_83f72_row0_col3" class="data row0 col3" >55%</td>
#     </tr>
#     <tr>
#       <th id="T_83f72_level0_row1" class="row_heading level0 row1" >Asian</th>
#       <td id="T_83f72_row1_col0" class="data row1 col0" >12%</td>
#       <td id="T_83f72_row1_col1" class="data row1 col1" >4%</td>
#       <td id="T_83f72_row1_col2" class="data row1 col2" >0%</td>
#       <td id="T_83f72_row1_col3" class="data row1 col3" >85%</td>
#     </tr>
#     <tr>
#       <th id="T_83f72_level0_row2" class="row_heading level0 row2" >Caucasian</th>
#       <td id="T_83f72_row2_col0" class="data row2 col0" >4%</td>
#       <td id="T_83f72_row2_col1" class="data row2 col1" >14%</td>
#       <td id="T_83f72_row2_col2" class="data row2 col2" >8%</td>
#       <td id="T_83f72_row2_col3" class="data row2 col3" >75%</td>
#     </tr>
#     <tr>
#       <th id="T_83f72_level0_row3" class="row_heading level0 row3" >Hispanic</th>
#       <td id="T_83f72_row3_col0" class="data row3 col0" >3%</td>
#       <td id="T_83f72_row3_col1" class="data row3 col1" >17%</td>
#       <td id="T_83f72_row3_col2" class="data row3 col2" >7%</td>
#       <td id="T_83f72_row3_col3" class="data row3 col3" >73%</td>
#     </tr>
#     <tr>
#       <th id="T_83f72_level0_row4" class="row_heading level0 row4" >Native American</th>
#       <td id="T_83f72_row4_col0" class="data row4 col0" >14%</td>
#       <td id="T_83f72_row4_col1" class="data row4 col1" >14%</td>
#       <td id="T_83f72_row4_col2" class="data row4 col2" >0%</td>
#       <td id="T_83f72_row4_col3" class="data row4 col3" >71%</td>
#     </tr>
#     <tr>
#       <th id="T_83f72_level0_row5" class="row_heading level0 row5" >Other</th>
#       <td id="T_83f72_row5_col0" class="data row5 col0" >7%</td>
#       <td id="T_83f72_row5_col1" class="data row5 col1" >13%</td>
#       <td id="T_83f72_row5_col2" class="data row5 col2" >7%</td>
#       <td id="T_83f72_row5_col3" class="data row5 col3" >74%</td>
#     </tr>
#   </tbody>
# </table>
# ************
#
# Table VIII - Top Panel - Proportion of Subtotals
# <style type="text/css">
# </style>
# <table id="T_dc4b3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Predicted</th>
#       <th id="T_dc4b3_level0_col0" class="col_heading level0 col0" colspan="2">1</th>
#       <th id="T_dc4b3_level0_col2" class="col_heading level0 col2" colspan="2">0</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Actual</th>
#       <th id="T_dc4b3_level1_col0" class="col_heading level1 col0" >1</th>
#       <th id="T_dc4b3_level1_col1" class="col_heading level1 col1" >0</th>
#       <th id="T_dc4b3_level1_col2" class="col_heading level1 col2" >1</th>
#       <th id="T_dc4b3_level1_col3" class="col_heading level1 col3" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc4b3_level0_row0" class="row_heading level0 row0" >African-American</th>
#       <td id="T_dc4b3_row0_col0" class="data row0 col0" >(35%)</td>
#       <td id="T_dc4b3_row0_col1" class="data row0 col1" >(65%)</td>
#       <td id="T_dc4b3_row0_col2" class="data row0 col2" >(13%)</td>
#       <td id="T_dc4b3_row0_col3" class="data row0 col3" >(87%)</td>
#     </tr>
#     <tr>
#       <th id="T_dc4b3_level0_row1" class="row_heading level0 row1" >Asian</th>
#       <td id="T_dc4b3_row1_col0" class="data row1 col0" >(75%)</td>
#       <td id="T_dc4b3_row1_col1" class="data row1 col1" >(25%)</td>
#       <td id="T_dc4b3_row1_col2" class="data row1 col2" >(0%)</td>
#       <td id="T_dc4b3_row1_col3" class="data row1 col3" >(100%)</td>
#     </tr>
#     <tr>
#       <th id="T_dc4b3_level0_row2" class="row_heading level0 row2" >Caucasian</th>
#       <td id="T_dc4b3_row2_col0" class="data row2 col0" >(24%)</td>
#       <td id="T_dc4b3_row2_col1" class="data row2 col1" >(76%)</td>
#       <td id="T_dc4b3_row2_col2" class="data row2 col2" >(9%)</td>
#       <td id="T_dc4b3_row2_col3" class="data row2 col3" >(91%)</td>
#     </tr>
#     <tr>
#       <th id="T_dc4b3_level0_row3" class="row_heading level0 row3" >Hispanic</th>
#       <td id="T_dc4b3_row3_col0" class="data row3 col0" >(14%)</td>
#       <td id="T_dc4b3_row3_col1" class="data row3 col1" >(86%)</td>
#       <td id="T_dc4b3_row3_col2" class="data row3 col2" >(9%)</td>
#       <td id="T_dc4b3_row3_col3" class="data row3 col3" >(91%)</td>
#     </tr>
#     <tr>
#       <th id="T_dc4b3_level0_row4" class="row_heading level0 row4" >Native American</th>
#       <td id="T_dc4b3_row4_col0" class="data row4 col0" >(50%)</td>
#       <td id="T_dc4b3_row4_col1" class="data row4 col1" >(50%)</td>
#       <td id="T_dc4b3_row4_col2" class="data row4 col2" >(0%)</td>
#       <td id="T_dc4b3_row4_col3" class="data row4 col3" >(100%)</td>
#     </tr>
#     <tr>
#       <th id="T_dc4b3_level0_row5" class="row_heading level0 row5" >Other</th>
#       <td id="T_dc4b3_row5_col0" class="data row5 col0" >(36%)</td>
#       <td id="T_dc4b3_row5_col1" class="data row5 col1" >(64%)</td>
#       <td id="T_dc4b3_row5_col2" class="data row5 col2" >(8%)</td>
#       <td id="T_dc4b3_row5_col3" class="data row5 col3" >(92%)</td>
#     </tr>
#   </tbody>
# </table>
# ************
#
# Table VIII - Bottom Panel - Proportion of Row Totals
# <style type="text/css">
# </style>
# <table id="T_834f4">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Actual</th>
#       <th id="T_834f4_level0_col0" class="col_heading level0 col0" colspan="2">1</th>
#       <th id="T_834f4_level0_col2" class="col_heading level0 col2" colspan="2">0</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted</th>
#       <th id="T_834f4_level1_col0" class="col_heading level1 col0" >1</th>
#       <th id="T_834f4_level1_col1" class="col_heading level1 col1" >0</th>
#       <th id="T_834f4_level1_col2" class="col_heading level1 col2" >1</th>
#       <th id="T_834f4_level1_col3" class="col_heading level1 col3" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_834f4_level0_row0" class="row_heading level0 row0" >African-American</th>
#       <td id="T_834f4_row0_col0" class="data row0 col0" >13%</td>
#       <td id="T_834f4_row0_col1" class="data row0 col1" >8%</td>
#       <td id="T_834f4_row0_col2" class="data row0 col2" >24%</td>
#       <td id="T_834f4_row0_col3" class="data row0 col3" >55%</td>
#     </tr>
#     <tr>
#       <th id="T_834f4_level0_row1" class="row_heading level0 row1" >Asian</th>
#       <td id="T_834f4_row1_col0" class="data row1 col0" >12%</td>
#       <td id="T_834f4_row1_col1" class="data row1 col1" >0%</td>
#       <td id="T_834f4_row1_col2" class="data row1 col2" >4%</td>
#       <td id="T_834f4_row1_col3" class="data row1 col3" >85%</td>
#     </tr>
#     <tr>
#       <th id="T_834f4_level0_row2" class="row_heading level0 row2" >Caucasian</th>
#       <td id="T_834f4_row2_col0" class="data row2 col0" >4%</td>
#       <td id="T_834f4_row2_col1" class="data row2 col1" >8%</td>
#       <td id="T_834f4_row2_col2" class="data row2 col2" >14%</td>
#       <td id="T_834f4_row2_col3" class="data row2 col3" >75%</td>
#     </tr>
#     <tr>
#       <th id="T_834f4_level0_row3" class="row_heading level0 row3" >Hispanic</th>
#       <td id="T_834f4_row3_col0" class="data row3 col0" >3%</td>
#       <td id="T_834f4_row3_col1" class="data row3 col1" >7%</td>
#       <td id="T_834f4_row3_col2" class="data row3 col2" >17%</td>
#       <td id="T_834f4_row3_col3" class="data row3 col3" >73%</td>
#     </tr>
#     <tr>
#       <th id="T_834f4_level0_row4" class="row_heading level0 row4" >Native American</th>
#       <td id="T_834f4_row4_col0" class="data row4 col0" >14%</td>
#       <td id="T_834f4_row4_col1" class="data row4 col1" >0%</td>
#       <td id="T_834f4_row4_col2" class="data row4 col2" >14%</td>
#       <td id="T_834f4_row4_col3" class="data row4 col3" >71%</td>
#     </tr>
#     <tr>
#       <th id="T_834f4_level0_row5" class="row_heading level0 row5" >Other</th>
#       <td id="T_834f4_row5_col0" class="data row5 col0" >7%</td>
#       <td id="T_834f4_row5_col1" class="data row5 col1" >7%</td>
#       <td id="T_834f4_row5_col2" class="data row5 col2" >13%</td>
#       <td id="T_834f4_row5_col3" class="data row5 col3" >74%</td>
#     </tr>
#   </tbody>
# </table>
# ************
#
# Table VIII - Bottom Panel - Proportion of Subtotals
# <style type="text/css">
# </style>
# <table id="T_3735d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Actual</th>
#       <th id="T_3735d_level0_col0" class="col_heading level0 col0" colspan="2">1</th>
#       <th id="T_3735d_level0_col2" class="col_heading level0 col2" colspan="2">0</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted</th>
#       <th id="T_3735d_level1_col0" class="col_heading level1 col0" >1</th>
#       <th id="T_3735d_level1_col1" class="col_heading level1 col1" >0</th>
#       <th id="T_3735d_level1_col2" class="col_heading level1 col2" >1</th>
#       <th id="T_3735d_level1_col3" class="col_heading level1 col3" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3735d_level0_row0" class="row_heading level0 row0" >African-American</th>
#       <td id="T_3735d_row0_col0" class="data row0 col0" >(62%)</td>
#       <td id="T_3735d_row0_col1" class="data row0 col1" >(38%)</td>
#       <td id="T_3735d_row0_col2" class="data row0 col2" >(31%)</td>
#       <td id="T_3735d_row0_col3" class="data row0 col3" >(69%)</td>
#     </tr>
#     <tr>
#       <th id="T_3735d_level0_row1" class="row_heading level0 row1" >Asian</th>
#       <td id="T_3735d_row1_col0" class="data row1 col0" >(100%)</td>
#       <td id="T_3735d_row1_col1" class="data row1 col1" >(0%)</td>
#       <td id="T_3735d_row1_col2" class="data row1 col2" >(4%)</td>
#       <td id="T_3735d_row1_col3" class="data row1 col3" >(96%)</td>
#     </tr>
#     <tr>
#       <th id="T_3735d_level0_row2" class="row_heading level0 row2" >Caucasian</th>
#       <td id="T_3735d_row2_col0" class="data row2 col0" >(37%)</td>
#       <td id="T_3735d_row2_col1" class="data row2 col1" >(63%)</td>
#       <td id="T_3735d_row2_col2" class="data row2 col2" >(15%)</td>
#       <td id="T_3735d_row2_col3" class="data row2 col3" >(85%)</td>
#     </tr>
#     <tr>
#       <th id="T_3735d_level0_row3" class="row_heading level0 row3" >Hispanic</th>
#       <td id="T_3735d_row3_col0" class="data row3 col0" >(29%)</td>
#       <td id="T_3735d_row3_col1" class="data row3 col1" >(71%)</td>
#       <td id="T_3735d_row3_col2" class="data row3 col2" >(19%)</td>
#       <td id="T_3735d_row3_col3" class="data row3 col3" >(81%)</td>
#     </tr>
#     <tr>
#       <th id="T_3735d_level0_row4" class="row_heading level0 row4" >Native American</th>
#       <td id="T_3735d_row4_col0" class="data row4 col0" >(100%)</td>
#       <td id="T_3735d_row4_col1" class="data row4 col1" >(0%)</td>
#       <td id="T_3735d_row4_col2" class="data row4 col2" >(17%)</td>
#       <td id="T_3735d_row4_col3" class="data row4 col3" >(83%)</td>
#     </tr>
#     <tr>
#       <th id="T_3735d_level0_row5" class="row_heading level0 row5" >Other</th>
#       <td id="T_3735d_row5_col0" class="data row5 col0" >(51%)</td>
#       <td id="T_3735d_row5_col1" class="data row5 col1" >(49%)</td>
#       <td id="T_3735d_row5_col2" class="data row5 col2" >(15%)</td>
#       <td id="T_3735d_row5_col3" class="data row5 col3" >(85%)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3) Intersectional Groups

# %%
result = ecf.ecf(sampledata=compasdata, s = 'intersection', pred = 'recid_pred', gt = 'recid_gt')

# %%
print('TABLE IX')
print('\n************\n')

print('Table IX - Observed (Columns O)')
display(result['contingency'].sort_index().reindex(sorted(result['contingency'].columns, reverse=True), axis=1))

print('\n************\n')

print('Table IX - Expected (Columns E)')
display(np.round(result['equal_confusion_test']['expected']).sort_index().reindex(sorted(result['equal_confusion_test']['expected'].columns, reverse=True), axis=1).style.format('{0:,.0f}'))

print('\n************\n')

print("Table IX - Residuals (Columns R)")
display(result['posthoc_analysis'].sort_index().reindex(sorted(result['posthoc_analysis'].columns, reverse=True), axis=1).round(1))
# Out:
# TABLE IX
#
# ************
#
# Table IX - Observed (Columns O)
# Actual                       1         0
# Predicted                    1    0    1    0
# Female - African-American   19   28   81  265
# Female - Asian               0    0    0    1
# Female - Caucasian           8   15   41  272
# Female - Hispanic            0    5    5   51
# Female - Other               0    2   10   38
# Male - African-American    231  126  387  781
# Male - Asian                 3    0    1   21
# Male - Caucasian            56   95  157  815
# Male - Hispanic             10   20   56  208
# Male - Native American       1    0    1    5
# Male - Other                18   15   22  150
# ************
#
# Table IX - Expected (Columns E)
# <style type="text/css">
# </style>
# <table id="T_daa7f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Actual</th>
#       <th id="T_daa7f_level0_col0" class="col_heading level0 col0" colspan="2">1</th>
#       <th id="T_daa7f_level0_col2" class="col_heading level0 col2" colspan="2">0</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted</th>
#       <th id="T_daa7f_level1_col0" class="col_heading level1 col0" >1</th>
#       <th id="T_daa7f_level1_col1" class="col_heading level1 col1" >0</th>
#       <th id="T_daa7f_level1_col2" class="col_heading level1 col2" >1</th>
#       <th id="T_daa7f_level1_col3" class="col_heading level1 col3" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_daa7f_level0_row0" class="row_heading level0 row0" >Female - African-American</th>
#       <td id="T_daa7f_row0_col0" class="data row0 col0" >34</td>
#       <td id="T_daa7f_row0_col1" class="data row0 col1" >30</td>
#       <td id="T_daa7f_row0_col2" class="data row0 col2" >74</td>
#       <td id="T_daa7f_row0_col3" class="data row0 col3" >255</td>
#     </tr>
#     <tr>
#       <th id="T_daa7f_level0_row1" class="row_heading level0 row1" >Female - Asian</th>
#       <td id="T_daa7f_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_daa7f_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_daa7f_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_daa7f_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_daa7f_level0_row2" class="row_heading level0 row2" >Female - Caucasian</th>
#       <td id="T_daa7f_row2_col0" class="data row2 col0" >29</td>
#       <td id="T_daa7f_row2_col1" class="data row2 col1" >26</td>
#       <td id="T_daa7f_row2_col2" class="data row2 col2" >64</td>
#       <td id="T_daa7f_row2_col3" class="data row2 col3" >218</td>
#     </tr>
#     <tr>
#       <th id="T_daa7f_level0_row3" class="row_heading level0 row3" >Female - Hispanic</th>
#       <td id="T_daa7f_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_daa7f_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_daa7f_row3_col2" class="data row3 col2" >12</td>
#       <td id="T_daa7f_row3_col3" class="data row3 col3" >40</td>
#     </tr>
#     <tr>
#       <th id="T_daa7f_level0_row4" class="row_heading level0 row4" >Female - Other</th>
#       <td id="T_daa7f_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_daa7f_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_daa7f_row4_col2" class="data row4 col2" >9</td>
#       <td id="T_daa7f_row4_col3" class="data row4 col3" >32</td>
#     </tr>
#     <tr>
#       <th id="T_daa7f_level0_row5" class="row_heading level0 row5" >Male - African-American</th>
#       <td id="T_daa7f_row5_col0" class="data row5 col0" >131</td>
#       <td id="T_daa7f_row5_col1" class="data row5 col1" >116</td>
#       <td id="T_daa7f_row5_col2" class="data row5 col2" >289</td>
#       <td id="T_daa7f_row5_col3" class="data row5 col3" >989</td>
#     </tr>
#     <tr>
#       <th id="T_daa7f_level0_row6" class="row_heading level0 row6" >Male - Asian</th>
#       <td id="T_daa7f_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_daa7f_row6_col1" class="data row6 col1" >2</td>
#       <td id="T_daa7f_row6_col2" class="data row6 col2" >5</td>
#       <td id="T_daa7f_row6_col3" class="data row6 col3" >16</td>
#     </tr>
#     <tr>
#       <th id="T_daa7f_level0_row7" class="row_heading level0 row7" >Male - Caucasian</th>
#       <td id="T_daa7f_row7_col0" class="data row7 col0" >97</td>
#       <td id="T_daa7f_row7_col1" class="data row7 col1" >85</td>
#       <td id="T_daa7f_row7_col2" class="data row7 col2" >213</td>
#       <td id="T_daa7f_row7_col3" class="data row7 col3" >728</td>
#     </tr>
#     <tr>
#       <th id="T_daa7f_level0_row8" class="row_heading level0 row8" >Male - Hispanic</th>
#       <td id="T_daa7f_row8_col0" class="data row8 col0" >25</td>
#       <td id="T_daa7f_row8_col1" class="data row8 col1" >22</td>
#       <td id="T_daa7f_row8_col2" class="data row8 col2" >56</td>
#       <td id="T_daa7f_row8_col3" class="data row8 col3" >191</td>
#     </tr>
#     <tr>
#       <th id="T_daa7f_level0_row9" class="row_heading level0 row9" >Male - Native American</th>
#       <td id="T_daa7f_row9_col0" class="data row9 col0" >1</td>
#       <td id="T_daa7f_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_daa7f_row9_col2" class="data row9 col2" >1</td>
#       <td id="T_daa7f_row9_col3" class="data row9 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_daa7f_level0_row10" class="row_heading level0 row10" >Male - Other</th>
#       <td id="T_daa7f_row10_col0" class="data row10 col0" >18</td>
#       <td id="T_daa7f_row10_col1" class="data row10 col1" >16</td>
#       <td id="T_daa7f_row10_col2" class="data row10 col2" >39</td>
#       <td id="T_daa7f_row10_col3" class="data row10 col3" >133</td>
#     </tr>
#   </tbody>
# </table>
# ************
#
# Table IX - Residuals (Columns R)
# Actual                        1         0
# Predicted                     1    0    1     0
# Female - African-American  -2.8 -0.4  0.9   1.1
# Female - Asian             -0.3 -0.3 -0.5   0.7
# Female - Caucasian         -4.3 -2.3 -3.3   6.5
# Female - Hispanic          -2.4  0.2 -2.2   3.1
# Female - Other             -2.2 -1.0  0.2   1.7
# Male - African-American    11.6  1.2  8.2 -14.2
# Male - Asian                0.6 -1.4 -1.9   2.0
# Male - Caucasian           -5.1  1.3 -5.0   6.4
# Male - Hispanic            -3.3 -0.5  0.1   2.2
# Male - Native American      0.5 -0.8 -0.3   0.4
# Male - Other                0.1 -0.2 -3.1   2.6

# %%
print('Intersectional Groups: Equal confusion test p-value is', round(result['equal_confusion_test']['p'], 5))

print('\n************\n')

print('Intersectional Groups: Confusion parity error is', round(result['confusion_parity_error'], 3))
# Out:
# Intersectional Groups: Equal confusion test p-value is 0.0
#
# ************
#
# Intersectional Groups: Confusion parity error is 0.156

# %%
print('TABLE X')
print('\n************\n')


print("Table X - Top Panel - Proportion of Row Totals")
display((result['ratio_all'][1]*100).sort_index().sort_index(axis=1, ascending=False).style.format('{0:,.0f}%'))

print('\n************\n')

print("Table X - Top Panel - Proportion of Subtotals")
display((result['ratio_pred']*100).sort_index().sort_index(axis=1, ascending=False).style.format('({0:,.0f}%)'))

print('\n************\n')

print("Table X - Bottom Panel - Proportion of Row Totals")
display((result['ratio_all'][0]*100).sort_index().sort_index(axis=1, ascending=False).style.format('{0:,.0f}%'))

print('\n************\n')

print("Table X - Bottom Panel - Proportion of Subtotals")
display((result['ratio_gt']*100).sort_index().sort_index(axis=1, ascending=False).style.format('({0:,.0f}%)'))
# Out:
# TABLE X
#
# ************
#
# Table X - Top Panel - Proportion of Row Totals
# <style type="text/css">
# </style>
# <table id="T_f964d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Predicted</th>
#       <th id="T_f964d_level0_col0" class="col_heading level0 col0" colspan="2">1</th>
#       <th id="T_f964d_level0_col2" class="col_heading level0 col2" colspan="2">0</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Actual</th>
#       <th id="T_f964d_level1_col0" class="col_heading level1 col0" >1</th>
#       <th id="T_f964d_level1_col1" class="col_heading level1 col1" >0</th>
#       <th id="T_f964d_level1_col2" class="col_heading level1 col2" >1</th>
#       <th id="T_f964d_level1_col3" class="col_heading level1 col3" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f964d_level0_row0" class="row_heading level0 row0" >Female - African-American</th>
#       <td id="T_f964d_row0_col0" class="data row0 col0" >5%</td>
#       <td id="T_f964d_row0_col1" class="data row0 col1" >21%</td>
#       <td id="T_f964d_row0_col2" class="data row0 col2" >7%</td>
#       <td id="T_f964d_row0_col3" class="data row0 col3" >67%</td>
#     </tr>
#     <tr>
#       <th id="T_f964d_level0_row1" class="row_heading level0 row1" >Female - Asian</th>
#       <td id="T_f964d_row1_col0" class="data row1 col0" >0%</td>
#       <td id="T_f964d_row1_col1" class="data row1 col1" >0%</td>
#       <td id="T_f964d_row1_col2" class="data row1 col2" >0%</td>
#       <td id="T_f964d_row1_col3" class="data row1 col3" >100%</td>
#     </tr>
#     <tr>
#       <th id="T_f964d_level0_row2" class="row_heading level0 row2" >Female - Caucasian</th>
#       <td id="T_f964d_row2_col0" class="data row2 col0" >2%</td>
#       <td id="T_f964d_row2_col1" class="data row2 col1" >12%</td>
#       <td id="T_f964d_row2_col2" class="data row2 col2" >4%</td>
#       <td id="T_f964d_row2_col3" class="data row2 col3" >81%</td>
#     </tr>
#     <tr>
#       <th id="T_f964d_level0_row3" class="row_heading level0 row3" >Female - Hispanic</th>
#       <td id="T_f964d_row3_col0" class="data row3 col0" >0%</td>
#       <td id="T_f964d_row3_col1" class="data row3 col1" >8%</td>
#       <td id="T_f964d_row3_col2" class="data row3 col2" >8%</td>
#       <td id="T_f964d_row3_col3" class="data row3 col3" >84%</td>
#     </tr>
#     <tr>
#       <th id="T_f964d_level0_row4" class="row_heading level0 row4" >Female - Other</th>
#       <td id="T_f964d_row4_col0" class="data row4 col0" >0%</td>
#       <td id="T_f964d_row4_col1" class="data row4 col1" >20%</td>
#       <td id="T_f964d_row4_col2" class="data row4 col2" >4%</td>
#       <td id="T_f964d_row4_col3" class="data row4 col3" >76%</td>
#     </tr>
#     <tr>
#       <th id="T_f964d_level0_row5" class="row_heading level0 row5" >Male - African-American</th>
#       <td id="T_f964d_row5_col0" class="data row5 col0" >15%</td>
#       <td id="T_f964d_row5_col1" class="data row5 col1" >25%</td>
#       <td id="T_f964d_row5_col2" class="data row5 col2" >8%</td>
#       <td id="T_f964d_row5_col3" class="data row5 col3" >51%</td>
#     </tr>
#     <tr>
#       <th id="T_f964d_level0_row6" class="row_heading level0 row6" >Male - Asian</th>
#       <td id="T_f964d_row6_col0" class="data row6 col0" >12%</td>
#       <td id="T_f964d_row6_col1" class="data row6 col1" >4%</td>
#       <td id="T_f964d_row6_col2" class="data row6 col2" >0%</td>
#       <td id="T_f964d_row6_col3" class="data row6 col3" >84%</td>
#     </tr>
#     <tr>
#       <th id="T_f964d_level0_row7" class="row_heading level0 row7" >Male - Caucasian</th>
#       <td id="T_f964d_row7_col0" class="data row7 col0" >5%</td>
#       <td id="T_f964d_row7_col1" class="data row7 col1" >14%</td>
#       <td id="T_f964d_row7_col2" class="data row7 col2" >8%</td>
#       <td id="T_f964d_row7_col3" class="data row7 col3" >73%</td>
#     </tr>
#     <tr>
#       <th id="T_f964d_level0_row8" class="row_heading level0 row8" >Male - Hispanic</th>
#       <td id="T_f964d_row8_col0" class="data row8 col0" >3%</td>
#       <td id="T_f964d_row8_col1" class="data row8 col1" >19%</td>
#       <td id="T_f964d_row8_col2" class="data row8 col2" >7%</td>
#       <td id="T_f964d_row8_col3" class="data row8 col3" >71%</td>
#     </tr>
#     <tr>
#       <th id="T_f964d_level0_row9" class="row_heading level0 row9" >Male - Native American</th>
#       <td id="T_f964d_row9_col0" class="data row9 col0" >14%</td>
#       <td id="T_f964d_row9_col1" class="data row9 col1" >14%</td>
#       <td id="T_f964d_row9_col2" class="data row9 col2" >0%</td>
#       <td id="T_f964d_row9_col3" class="data row9 col3" >71%</td>
#     </tr>
#     <tr>
#       <th id="T_f964d_level0_row10" class="row_heading level0 row10" >Male - Other</th>
#       <td id="T_f964d_row10_col0" class="data row10 col0" >9%</td>
#       <td id="T_f964d_row10_col1" class="data row10 col1" >11%</td>
#       <td id="T_f964d_row10_col2" class="data row10 col2" >7%</td>
#       <td id="T_f964d_row10_col3" class="data row10 col3" >73%</td>
#     </tr>
#   </tbody>
# </table>
# ************
#
# Table X - Top Panel - Proportion of Subtotals
# <style type="text/css">
# </style>
# <table id="T_d3d07">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Predicted</th>
#       <th id="T_d3d07_level0_col0" class="col_heading level0 col0" colspan="2">1</th>
#       <th id="T_d3d07_level0_col2" class="col_heading level0 col2" colspan="2">0</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Actual</th>
#       <th id="T_d3d07_level1_col0" class="col_heading level1 col0" >1</th>
#       <th id="T_d3d07_level1_col1" class="col_heading level1 col1" >0</th>
#       <th id="T_d3d07_level1_col2" class="col_heading level1 col2" >1</th>
#       <th id="T_d3d07_level1_col3" class="col_heading level1 col3" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3d07_level0_row0" class="row_heading level0 row0" >Female - African-American</th>
#       <td id="T_d3d07_row0_col0" class="data row0 col0" >(19%)</td>
#       <td id="T_d3d07_row0_col1" class="data row0 col1" >(81%)</td>
#       <td id="T_d3d07_row0_col2" class="data row0 col2" >(10%)</td>
#       <td id="T_d3d07_row0_col3" class="data row0 col3" >(90%)</td>
#     </tr>
#     <tr>
#       <th id="T_d3d07_level0_row1" class="row_heading level0 row1" >Female - Asian</th>
#       <td id="T_d3d07_row1_col0" class="data row1 col0" >(nan%)</td>
#       <td id="T_d3d07_row1_col1" class="data row1 col1" >(nan%)</td>
#       <td id="T_d3d07_row1_col2" class="data row1 col2" >(0%)</td>
#       <td id="T_d3d07_row1_col3" class="data row1 col3" >(100%)</td>
#     </tr>
#     <tr>
#       <th id="T_d3d07_level0_row2" class="row_heading level0 row2" >Female - Caucasian</th>
#       <td id="T_d3d07_row2_col0" class="data row2 col0" >(16%)</td>
#       <td id="T_d3d07_row2_col1" class="data row2 col1" >(84%)</td>
#       <td id="T_d3d07_row2_col2" class="data row2 col2" >(5%)</td>
#       <td id="T_d3d07_row2_col3" class="data row2 col3" >(95%)</td>
#     </tr>
#     <tr>
#       <th id="T_d3d07_level0_row3" class="row_heading level0 row3" >Female - Hispanic</th>
#       <td id="T_d3d07_row3_col0" class="data row3 col0" >(0%)</td>
#       <td id="T_d3d07_row3_col1" class="data row3 col1" >(100%)</td>
#       <td id="T_d3d07_row3_col2" class="data row3 col2" >(9%)</td>
#       <td id="T_d3d07_row3_col3" class="data row3 col3" >(91%)</td>
#     </tr>
#     <tr>
#       <th id="T_d3d07_level0_row4" class="row_heading level0 row4" >Female - Other</th>
#       <td id="T_d3d07_row4_col0" class="data row4 col0" >(0%)</td>
#       <td id="T_d3d07_row4_col1" class="data row4 col1" >(100%)</td>
#       <td id="T_d3d07_row4_col2" class="data row4 col2" >(5%)</td>
#       <td id="T_d3d07_row4_col3" class="data row4 col3" >(95%)</td>
#     </tr>
#     <tr>
#       <th id="T_d3d07_level0_row5" class="row_heading level0 row5" >Male - African-American</th>
#       <td id="T_d3d07_row5_col0" class="data row5 col0" >(37%)</td>
#       <td id="T_d3d07_row5_col1" class="data row5 col1" >(63%)</td>
#       <td id="T_d3d07_row5_col2" class="data row5 col2" >(14%)</td>
#       <td id="T_d3d07_row5_col3" class="data row5 col3" >(86%)</td>
#     </tr>
#     <tr>
#       <th id="T_d3d07_level0_row6" class="row_heading level0 row6" >Male - Asian</th>
#       <td id="T_d3d07_row6_col0" class="data row6 col0" >(75%)</td>
#       <td id="T_d3d07_row6_col1" class="data row6 col1" >(25%)</td>
#       <td id="T_d3d07_row6_col2" class="data row6 col2" >(0%)</td>
#       <td id="T_d3d07_row6_col3" class="data row6 col3" >(100%)</td>
#     </tr>
#     <tr>
#       <th id="T_d3d07_level0_row7" class="row_heading level0 row7" >Male - Caucasian</th>
#       <td id="T_d3d07_row7_col0" class="data row7 col0" >(26%)</td>
#       <td id="T_d3d07_row7_col1" class="data row7 col1" >(74%)</td>
#       <td id="T_d3d07_row7_col2" class="data row7 col2" >(10%)</td>
#       <td id="T_d3d07_row7_col3" class="data row7 col3" >(90%)</td>
#     </tr>
#     <tr>
#       <th id="T_d3d07_level0_row8" class="row_heading level0 row8" >Male - Hispanic</th>
#       <td id="T_d3d07_row8_col0" class="data row8 col0" >(15%)</td>
#       <td id="T_d3d07_row8_col1" class="data row8 col1" >(85%)</td>
#       <td id="T_d3d07_row8_col2" class="data row8 col2" >(9%)</td>
#       <td id="T_d3d07_row8_col3" class="data row8 col3" >(91%)</td>
#     </tr>
#     <tr>
#       <th id="T_d3d07_level0_row9" class="row_heading level0 row9" >Male - Native American</th>
#       <td id="T_d3d07_row9_col0" class="data row9 col0" >(50%)</td>
#       <td id="T_d3d07_row9_col1" class="data row9 col1" >(50%)</td>
#       <td id="T_d3d07_row9_col2" class="data row9 col2" >(0%)</td>
#       <td id="T_d3d07_row9_col3" class="data row9 col3" >(100%)</td>
#     </tr>
#     <tr>
#       <th id="T_d3d07_level0_row10" class="row_heading level0 row10" >Male - Other</th>
#       <td id="T_d3d07_row10_col0" class="data row10 col0" >(45%)</td>
#       <td id="T_d3d07_row10_col1" class="data row10 col1" >(55%)</td>
#       <td id="T_d3d07_row10_col2" class="data row10 col2" >(9%)</td>
#       <td id="T_d3d07_row10_col3" class="data row10 col3" >(91%)</td>
#     </tr>
#   </tbody>
# </table>
# ************
#
# Table X - Bottom Panel - Proportion of Row Totals
# <style type="text/css">
# </style>
# <table id="T_97918">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Actual</th>
#       <th id="T_97918_level0_col0" class="col_heading level0 col0" colspan="2">1</th>
#       <th id="T_97918_level0_col2" class="col_heading level0 col2" colspan="2">0</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted</th>
#       <th id="T_97918_level1_col0" class="col_heading level1 col0" >1</th>
#       <th id="T_97918_level1_col1" class="col_heading level1 col1" >0</th>
#       <th id="T_97918_level1_col2" class="col_heading level1 col2" >1</th>
#       <th id="T_97918_level1_col3" class="col_heading level1 col3" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97918_level0_row0" class="row_heading level0 row0" >Female - African-American</th>
#       <td id="T_97918_row0_col0" class="data row0 col0" >5%</td>
#       <td id="T_97918_row0_col1" class="data row0 col1" >7%</td>
#       <td id="T_97918_row0_col2" class="data row0 col2" >21%</td>
#       <td id="T_97918_row0_col3" class="data row0 col3" >67%</td>
#     </tr>
#     <tr>
#       <th id="T_97918_level0_row1" class="row_heading level0 row1" >Female - Asian</th>
#       <td id="T_97918_row1_col0" class="data row1 col0" >0%</td>
#       <td id="T_97918_row1_col1" class="data row1 col1" >0%</td>
#       <td id="T_97918_row1_col2" class="data row1 col2" >0%</td>
#       <td id="T_97918_row1_col3" class="data row1 col3" >100%</td>
#     </tr>
#     <tr>
#       <th id="T_97918_level0_row2" class="row_heading level0 row2" >Female - Caucasian</th>
#       <td id="T_97918_row2_col0" class="data row2 col0" >2%</td>
#       <td id="T_97918_row2_col1" class="data row2 col1" >4%</td>
#       <td id="T_97918_row2_col2" class="data row2 col2" >12%</td>
#       <td id="T_97918_row2_col3" class="data row2 col3" >81%</td>
#     </tr>
#     <tr>
#       <th id="T_97918_level0_row3" class="row_heading level0 row3" >Female - Hispanic</th>
#       <td id="T_97918_row3_col0" class="data row3 col0" >0%</td>
#       <td id="T_97918_row3_col1" class="data row3 col1" >8%</td>
#       <td id="T_97918_row3_col2" class="data row3 col2" >8%</td>
#       <td id="T_97918_row3_col3" class="data row3 col3" >84%</td>
#     </tr>
#     <tr>
#       <th id="T_97918_level0_row4" class="row_heading level0 row4" >Female - Other</th>
#       <td id="T_97918_row4_col0" class="data row4 col0" >0%</td>
#       <td id="T_97918_row4_col1" class="data row4 col1" >4%</td>
#       <td id="T_97918_row4_col2" class="data row4 col2" >20%</td>
#       <td id="T_97918_row4_col3" class="data row4 col3" >76%</td>
#     </tr>
#     <tr>
#       <th id="T_97918_level0_row5" class="row_heading level0 row5" >Male - African-American</th>
#       <td id="T_97918_row5_col0" class="data row5 col0" >15%</td>
#       <td id="T_97918_row5_col1" class="data row5 col1" >8%</td>
#       <td id="T_97918_row5_col2" class="data row5 col2" >25%</td>
#       <td id="T_97918_row5_col3" class="data row5 col3" >51%</td>
#     </tr>
#     <tr>
#       <th id="T_97918_level0_row6" class="row_heading level0 row6" >Male - Asian</th>
#       <td id="T_97918_row6_col0" class="data row6 col0" >12%</td>
#       <td id="T_97918_row6_col1" class="data row6 col1" >0%</td>
#       <td id="T_97918_row6_col2" class="data row6 col2" >4%</td>
#       <td id="T_97918_row6_col3" class="data row6 col3" >84%</td>
#     </tr>
#     <tr>
#       <th id="T_97918_level0_row7" class="row_heading level0 row7" >Male - Caucasian</th>
#       <td id="T_97918_row7_col0" class="data row7 col0" >5%</td>
#       <td id="T_97918_row7_col1" class="data row7 col1" >8%</td>
#       <td id="T_97918_row7_col2" class="data row7 col2" >14%</td>
#       <td id="T_97918_row7_col3" class="data row7 col3" >73%</td>
#     </tr>
#     <tr>
#       <th id="T_97918_level0_row8" class="row_heading level0 row8" >Male - Hispanic</th>
#       <td id="T_97918_row8_col0" class="data row8 col0" >3%</td>
#       <td id="T_97918_row8_col1" class="data row8 col1" >7%</td>
#       <td id="T_97918_row8_col2" class="data row8 col2" >19%</td>
#       <td id="T_97918_row8_col3" class="data row8 col3" >71%</td>
#     </tr>
#     <tr>
#       <th id="T_97918_level0_row9" class="row_heading level0 row9" >Male - Native American</th>
#       <td id="T_97918_row9_col0" class="data row9 col0" >14%</td>
#       <td id="T_97918_row9_col1" class="data row9 col1" >0%</td>
#       <td id="T_97918_row9_col2" class="data row9 col2" >14%</td>
#       <td id="T_97918_row9_col3" class="data row9 col3" >71%</td>
#     </tr>
#     <tr>
#       <th id="T_97918_level0_row10" class="row_heading level0 row10" >Male - Other</th>
#       <td id="T_97918_row10_col0" class="data row10 col0" >9%</td>
#       <td id="T_97918_row10_col1" class="data row10 col1" >7%</td>
#       <td id="T_97918_row10_col2" class="data row10 col2" >11%</td>
#       <td id="T_97918_row10_col3" class="data row10 col3" >73%</td>
#     </tr>
#   </tbody>
# </table>
# ************
#
# Table X - Bottom Panel - Proportion of Subtotals
# <style type="text/css">
# </style>
# <table id="T_dd9db">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Actual</th>
#       <th id="T_dd9db_level0_col0" class="col_heading level0 col0" colspan="2">1</th>
#       <th id="T_dd9db_level0_col2" class="col_heading level0 col2" colspan="2">0</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted</th>
#       <th id="T_dd9db_level1_col0" class="col_heading level1 col0" >1</th>
#       <th id="T_dd9db_level1_col1" class="col_heading level1 col1" >0</th>
#       <th id="T_dd9db_level1_col2" class="col_heading level1 col2" >1</th>
#       <th id="T_dd9db_level1_col3" class="col_heading level1 col3" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd9db_level0_row0" class="row_heading level0 row0" >Female - African-American</th>
#       <td id="T_dd9db_row0_col0" class="data row0 col0" >(40%)</td>
#       <td id="T_dd9db_row0_col1" class="data row0 col1" >(60%)</td>
#       <td id="T_dd9db_row0_col2" class="data row0 col2" >(23%)</td>
#       <td id="T_dd9db_row0_col3" class="data row0 col3" >(77%)</td>
#     </tr>
#     <tr>
#       <th id="T_dd9db_level0_row1" class="row_heading level0 row1" >Female - Asian</th>
#       <td id="T_dd9db_row1_col0" class="data row1 col0" >(nan%)</td>
#       <td id="T_dd9db_row1_col1" class="data row1 col1" >(nan%)</td>
#       <td id="T_dd9db_row1_col2" class="data row1 col2" >(0%)</td>
#       <td id="T_dd9db_row1_col3" class="data row1 col3" >(100%)</td>
#     </tr>
#     <tr>
#       <th id="T_dd9db_level0_row2" class="row_heading level0 row2" >Female - Caucasian</th>
#       <td id="T_dd9db_row2_col0" class="data row2 col0" >(35%)</td>
#       <td id="T_dd9db_row2_col1" class="data row2 col1" >(65%)</td>
#       <td id="T_dd9db_row2_col2" class="data row2 col2" >(13%)</td>
#       <td id="T_dd9db_row2_col3" class="data row2 col3" >(87%)</td>
#     </tr>
#     <tr>
#       <th id="T_dd9db_level0_row3" class="row_heading level0 row3" >Female - Hispanic</th>
#       <td id="T_dd9db_row3_col0" class="data row3 col0" >(0%)</td>
#       <td id="T_dd9db_row3_col1" class="data row3 col1" >(100%)</td>
#       <td id="T_dd9db_row3_col2" class="data row3 col2" >(9%)</td>
#       <td id="T_dd9db_row3_col3" class="data row3 col3" >(91%)</td>
#     </tr>
#     <tr>
#       <th id="T_dd9db_level0_row4" class="row_heading level0 row4" >Female - Other</th>
#       <td id="T_dd9db_row4_col0" class="data row4 col0" >(0%)</td>
#       <td id="T_dd9db_row4_col1" class="data row4 col1" >(100%)</td>
#       <td id="T_dd9db_row4_col2" class="data row4 col2" >(21%)</td>
#       <td id="T_dd9db_row4_col3" class="data row4 col3" >(79%)</td>
#     </tr>
#     <tr>
#       <th id="T_dd9db_level0_row5" class="row_heading level0 row5" >Male - African-American</th>
#       <td id="T_dd9db_row5_col0" class="data row5 col0" >(65%)</td>
#       <td id="T_dd9db_row5_col1" class="data row5 col1" >(35%)</td>
#       <td id="T_dd9db_row5_col2" class="data row5 col2" >(33%)</td>
#       <td id="T_dd9db_row5_col3" class="data row5 col3" >(67%)</td>
#     </tr>
#     <tr>
#       <th id="T_dd9db_level0_row6" class="row_heading level0 row6" >Male - Asian</th>
#       <td id="T_dd9db_row6_col0" class="data row6 col0" >(100%)</td>
#       <td id="T_dd9db_row6_col1" class="data row6 col1" >(0%)</td>
#       <td id="T_dd9db_row6_col2" class="data row6 col2" >(5%)</td>
#       <td id="T_dd9db_row6_col3" class="data row6 col3" >(95%)</td>
#     </tr>
#     <tr>
#       <th id="T_dd9db_level0_row7" class="row_heading level0 row7" >Male - Caucasian</th>
#       <td id="T_dd9db_row7_col0" class="data row7 col0" >(37%)</td>
#       <td id="T_dd9db_row7_col1" class="data row7 col1" >(63%)</td>
#       <td id="T_dd9db_row7_col2" class="data row7 col2" >(16%)</td>
#       <td id="T_dd9db_row7_col3" class="data row7 col3" >(84%)</td>
#     </tr>
#     <tr>
#       <th id="T_dd9db_level0_row8" class="row_heading level0 row8" >Male - Hispanic</th>
#       <td id="T_dd9db_row8_col0" class="data row8 col0" >(33%)</td>
#       <td id="T_dd9db_row8_col1" class="data row8 col1" >(67%)</td>
#       <td id="T_dd9db_row8_col2" class="data row8 col2" >(21%)</td>
#       <td id="T_dd9db_row8_col3" class="data row8 col3" >(79%)</td>
#     </tr>
#     <tr>
#       <th id="T_dd9db_level0_row9" class="row_heading level0 row9" >Male - Native American</th>
#       <td id="T_dd9db_row9_col0" class="data row9 col0" >(100%)</td>
#       <td id="T_dd9db_row9_col1" class="data row9 col1" >(0%)</td>
#       <td id="T_dd9db_row9_col2" class="data row9 col2" >(17%)</td>
#       <td id="T_dd9db_row9_col3" class="data row9 col3" >(83%)</td>
#     </tr>
#     <tr>
#       <th id="T_dd9db_level0_row10" class="row_heading level0 row10" >Male - Other</th>
#       <td id="T_dd9db_row10_col0" class="data row10 col0" >(55%)</td>
#       <td id="T_dd9db_row10_col1" class="data row10 col1" >(45%)</td>
#       <td id="T_dd9db_row10_col2" class="data row10 col2" >(13%)</td>
#       <td id="T_dd9db_row10_col3" class="data row10 col3" >(87%)</td>
#     </tr>
#   </tbody>
# </table>
